# %% [markdown]
# Regression-->continuous value prediction
#
# classification-->categorical values
#
# binary classification---2 classification
#
# multiclass classification--morethan 2 classification
#
# sigmoid(z)=1/(1+e^(-z))
#
#
#
#
#
#
#
#
#
# **log loss:**
#
#
#
#
# confusion matrix-->
